# %% [markdown]
# Lab | Customer Analysis Round 5 For this lab, we still keep using the marketing_customer_analysis.csv file that you can find in the files_for_lab folder.
#
# 1. Get the data We are using the marketing_customer_analysis.csv file.
#
# 2. Dealing with the data Already done in the round 2.
#
# 3. Explore the data Done in the round 3.
#
# 4. Processing Data (Further processing...)
#
#     4.1. X-y split.
#     4.2. Normalize (numerical).

# %%
# 1. Get the data We are using the marketing_customer_analysis.csv file.
import pandas as pd
df=pd.read_csv(r"C:\Users\Usuari\Documents\IRONHACK\Work\Labs\01 semana\2023-03-09\marketing_customer_analysis.csv")
df.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
# 2. Dealing with the data Already done in the round 2.
df.dtypes
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
#3. Explore the data Done in the round 3.
df=df.dropna()

# %%
numericos=df.select_dtypes(include=["int64", "float64"])
numericos
# Out:
#        Unnamed: 0  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 10             10              5154.764074   82730                   127
# 13             13              5454.587929   66334                    69
# 16             16              5326.677654   76717                    66
# ...           ...                      ...     ...                   ...
# 10902       10902              3579.023825   28304                    91
# 10903       10903              2771.663013   59855                    74
# 10904       10904             19228.463620       0                   187
# 10906       10906              5259.444853   61146                    65
# 10908       10908             11971.977650   64195                   158
#
#        Months Since Last Claim  Months Since Policy Inception  \
# ...

# %%
categoricos=df.select_dtypes(exclude=["int64", "float64"])
categoricos
# Out:
#       Customer       State Response  Coverage             Education  \
# 2      LZ68649  Washington       No     Basic              Bachelor
# 3      XL78013      Oregon      Yes  Extended               College
# 10     HG93801     Arizona       No  Extended  High School or Below
# 13     KR82385  California       No     Basic                Master
# 16     FH51383  California       No     Basic  High School or Below
# ...        ...         ...      ...       ...                   ...
# 10902  PP30874  California       No  Extended  High School or Below
# 10903  SU71163     Arizona       No     Basic               College
# 10904  QI63521      Nevada       No     Basic  High School or Below
# 10906  KX53892      Oregon       No     Basic               College
# 10908  WA60547  California       No   Premium               College
#
#       Effective To Date EmploymentStatus Gender Location Code Marital Status  \
# ...

# %%
correlaciones=numericos.corr()
correlaciones
# Out:
#                                Unnamed: 0  Customer Lifetime Value    Income  \
# Unnamed: 0                       1.000000                 0.018506  0.002476
# Customer Lifetime Value          0.018506                 1.000000  0.015914
# Income                           0.002476                 0.015914  1.000000
# Monthly Premium Auto            -0.002327                 0.413739 -0.007594
# Months Since Last Claim         -0.012626                 0.029199 -0.010556
# Months Since Policy Inception    0.016022                 0.022465 -0.007987
# Number of Open Complaints       -0.007972                -0.034924  0.001149
# Number of Policies              -0.004518                 0.015397 -0.013199
# Total Claim Amount              -0.008315                 0.228579 -0.355311
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Unnamed: 0                                -0.002327                -0.012626
# ...

# %%
# 4. Processing Data (Further processing...)
    # 4.1. X-y split. 
x = df.drop(columns="Customer Lifetime Value")
y = df["Customer Lifetime Value"]

# %%
 # 4.2. Normalize (numerical).
from sklearn.preprocessing import MinMaxScaler  
scaler=MinMaxScaler()
nomalized_df=scaler.fit_transform(df.select_dtypes(include=["int64", "float64"]))
nomalized_df
# Out:
# array([[0.00000000e+00, 1.60202595e-01, 2.21476376e-01, ...,
#         0.00000000e+00, 1.25000000e-01, 1.65875444e-01],
#        [9.16926462e-05, 2.50897719e-01, 4.90971479e-01, ...,
#         0.00000000e+00, 1.25000000e-01, 1.67262660e-01],
#        [7.33541170e-04, 3.99251795e-02, 8.27622773e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 1.52921040e-01],
#        ...,
#        [9.99633229e-01, 2.12775351e-01, 0.00000000e+00, ...,
#         0.00000000e+00, 1.25000000e-01, 3.10216853e-01],
#        [9.99816615e-01, 4.12108464e-02, 6.11698562e-01, ...,
#         0.00000000e+00, 6.25000000e-01, 9.43334435e-02],
#        [1.00000000e+00, 1.23652740e-01, 6.42200458e-01, ...,
#         8.00000000e-01, 6.25000000e-01, 2.13674312e-01]])

# %%
y1=pd.DataFrame(nomalized_df, columns=df.select_dtypes(include=["int64", "float64"]).columns)
y1
# Out:
#       Unnamed: 0  Customer Lifetime Value    Income  Monthly Premium Auto  \
# 0       0.000000                 0.160203  0.221476              0.164557
# 1       0.000092                 0.250898  0.490971              0.151899
# 2       0.000734                 0.039925  0.827623              0.278481
# 3       0.001009                 0.043608  0.663599              0.033755
# 4       0.001284                 0.042037  0.767469              0.021097
# ...          ...                      ...       ...                   ...
# 4538    0.999450                 0.020572  0.283150              0.126582
# 4539    0.999542                 0.010656  0.598784              0.054852
# 4540    0.999633                 0.212775  0.000000              0.531646
# 4541    0.999817                 0.041211  0.611699              0.016878
# 4542    1.000000                 0.123653  0.642200              0.409283
#
#       Months Since Last Claim  Months Since Policy Inception  \
# ...
